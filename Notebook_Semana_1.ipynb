# %% [markdown]
# <a href="https://colab.research.google.com/github/juanpsantosm-droid/Notebooks_Agro-2026-01/blob/main/Notebook_Semana_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Entrada: Entra ancho y alto de la madera en metros
ancho = input("Ingresa el ancho de la ventana en metros ")
ancho = float(ancho)
alto = input("Ingresa el alto de la ventana en metros ")
alto = float(alto)
# Proceso: Calcula longitud de la madera (lm) en pies
# y el Area del vidrio en metros cuadrados
lm = 2*(ancho + alto)*3.25
av = 2*(ancho * alto)

# Salida: sale la longitud de la madera en pies
# y el Area del vidrio en metros cuadrados
print("La Longitud de la madera es", lm," pies de longitud")
print("El Area del vidrio es",av, " metros cuadrados")
# Out:
# Ingresa el ancho de la ventana en metros 36
# Ingresa el alto de la ventana en metros 47
# La Longitud de la madera es 539.5  pies de longitud
# El Area del vidrio es 3384.0  metros cuadrados
